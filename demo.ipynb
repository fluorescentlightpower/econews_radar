# %% [markdown]
# # 🌍 EcoNews Radar Demo
#
# AI-радар для автоматического выявления экологически значимых новостей
# на базе EnvironmentalBERT.

# %%
# Установка

# !pip install -r requirements.txt

# %%
from econews_radar import classify_news_or_logic

# %% [markdown]
# Пример обычной новости

# %%
regular_news = """
Apple released its new iPhone model today, featuring an improved camera and battery life.
Shares rose by 3% after the announcement.
"""
classify_news_or_logic(regular_news)

# %% [markdown]
# Пример экологической новости

# %%
eco_news = """
A chemical spill was reported near the river delta, threatening local wildlife and water quality.
Authorities are investigating possible contamination.
"""
classify_news_or_logic(eco_news)

# %% [markdown]
# ### Что показывает этот демонстрационный пример
#
# EcoNews Radar спроектирован как **первый фильтрующий слой ESG-мониторинга**.
# Он выполняет раннее выявление экологически значимых новостей и направляет только релевантные материалы на последующий, более глубокий анализ.
